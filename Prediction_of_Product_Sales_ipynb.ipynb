# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielleYa/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Prediction of Product Sales**

# %% [markdown]
# - **Author:** Gabrielle Ray

# %% [markdown]
# ## **Project Overview**

# %% [markdown]
# ## **Load and Inspect Data**

# %% [markdown]
# ## **Clean Data**

# %% [markdown]
# ## **Explanatory Data Analysis**

# %% [markdown]
# ## **Featured Inspection**
